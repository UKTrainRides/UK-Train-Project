# %% [markdown]
# # Data-Driven Analysis of the UK Railway Network

# %% [markdown]
# ![OBC-diagram-1000x700.webp](attachment:503876e1-8791-4719-9c2f-92f5aebe7b21.webp)

# %% [markdown]
# # Project Objective: UK Trains Analysis
#
# The objective of this project is to analyze UK train data to understand performance, usage patterns, and operational efficiency across the railway network.
#
# This project aims to:
#
# - Examine train schedules, routes, and station activity across the UK.
# - Analyze delays, cancellations, and punctuality performance.
# - Identify peak travel times and high-traffic routes.
# - Explore factors that may impact service reliability.
# - Visualize key trends using clear and informative charts.
#
# By transforming raw railway data into meaningful insights, this project seeks to highlight performance patterns, improve decision-making, and support recommendations for enhancing the efficiency and reliability of the UK rail system.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Understanding Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
trains=pd.read_csv('railway.csv',index_col=0)
trains.head(5)
# Out:
#                         Date of Purchase Time of Purchase Purchase Type  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#                         Payment Method Railcard Ticket Class Ticket Type  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176    Contactless    Adult     Standard     Advance
# b0cdd1b0-f214-4197-be53    Credit Card    Adult     Standard     Advance
# f3ba7a96-f713-40d9-9629    Credit Card      NaN     Standard     Advance
# b2471f11-4fe7-4c87-8ab4    Credit Card      NaN     Standard     Advance
# 2be00b45-0762-485e-a7a3    Contactless      NaN     Standard     Advance
#
#                          Price      Departure Station    Arrival Destination  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176     43      London Paddington  Liverpool Lime Street
# b0cdd1b0-f214-4197-be53     23     London Kings Cross                   York
# f3ba7a96-f713-40d9-9629      3  Liverpool Lime Street  Manchester Piccadilly
# b2471f11-4fe7-4c87-8ab4     13      London Paddington                Reading
# 2be00b45-0762-485e-a7a3     76  Liverpool Lime Street          London Euston
#
#                         Date of Journey Departure Time Arrival Time  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176      2024-01-01       11:00:00     13:30:00
# b0cdd1b0-f214-4197-be53      2024-01-01       09:45:00     11:35:00
# f3ba7a96-f713-40d9-9629      2024-01-02       18:15:00     18:45:00
# b2471f11-4fe7-4c87-8ab4      2024-01-01       21:30:00     22:30:00
# 2be00b45-0762-485e-a7a3      2024-01-01       16:45:00     19:00:00
#
#                         Actual Arrival Time Journey Status Reason for Delay  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176            13:30:00        On Time              NaN
# b0cdd1b0-f214-4197-be53            11:40:00        Delayed   Signal Failure
# f3ba7a96-f713-40d9-9629            18:45:00        On Time              NaN
# b2471f11-4fe7-4c87-8ab4            22:30:00        On Time              NaN
# 2be00b45-0762-485e-a7a3            19:00:00        On Time              NaN
#
#                         Refund Request
# Transaction ID
# da8a6ba8-b3dc-4677-b176             No
# b0cdd1b0-f214-4197-be53             No
# f3ba7a96-f713-40d9-9629             No
# b2471f11-4fe7-4c87-8ab4             No
# 2be00b45-0762-485e-a7a3             No

# %% [markdown]
# ### check duplicates

# %%
trains.duplicated().sum()
# Out:
# np.int64(8)

# %% [markdown]
# ### delete duplicates

# %%
railway_cleaned = trains.drop_duplicates()
railway_cleaned = trains.drop_duplicates().copy()

# %% [markdown]
# ### check missing vales

# %%
railway_cleaned.isnull().sum()
# Out:
# Date of Purchase           0
# Time of Purchase           0
# Purchase Type              0
# Payment Method             0
# Railcard               20912
# Ticket Class               0
# Ticket Type                0
# Price                      0
# Departure Station          0
# Arrival Destination        0
# Date of Journey            0
# Departure Time             0
# Arrival Time               0
# Actual Arrival Time     1879
# Journey Status             0
# Reason for Delay       27476
# Refund Request             0
# dtype: int64

# %% [markdown]
# ### Handling Missing Values

# %%
missing = railway_cleaned[
    (railway_cleaned['Reason for Delay'].isna()) | (railway_cleaned['Reason for Delay'] == '') |
    (railway_cleaned['Actual Arrival Time'].isna()) | (railway_cleaned['Actual Arrival Time'] == '') |
    (railway_cleaned['Railcard'].isna()) | (railway_cleaned['Railcard'] == '')
]

# %%
railway_cleaned['Reason for Delay'] = railway_cleaned['Reason for Delay'].replace('', 'Not Mentioned')
railway_cleaned['Reason for Delay'] = railway_cleaned['Reason for Delay'].fillna('Not Mentioned')

railway_cleaned['Railcard'] = railway_cleaned['Railcard'].replace(['', 'None'], 'No Railcard')
railway_cleaned['Railcard'] = railway_cleaned['Railcard'].fillna('No Railcard')

railway_cleaned['Actual Arrival Time'] = railway_cleaned['Actual Arrival Time'].replace('', '00:00:00')
railway_cleaned['Actual Arrival Time'] = railway_cleaned['Actual Arrival Time'].fillna('00:00:00')

# %% [markdown]
# ### Check Outliers

# %%
outliers = railway_cleaned[railway_cleaned['Price'] > 300]

# %%
railway_cleaned.head(10)
# Out:
#                         Date of Purchase Time of Purchase Purchase Type  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
# 4e1dcd88-3d95-44ef-99fa       2023-12-30         07:56:06        Online
# 1c74479d-85a4-4ba1-a607       2023-12-31         00:02:01       Station
# febf8dab-f808-46fa-bf2b       2023-12-31         01:35:18       Station
# 01df916f-4291-41ec-a37d       2023-12-31         01:43:09       Station
# a8cedba7-1923-459d-b046       2023-12-31         03:05:52        Online
#
#                         Payment Method     Railcard Ticket Class Ticket Type  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176    Contactless        Adult     Standard     Advance
# b0cdd1b0-f214-4197-be53    Credit Card        Adult     Standard     Advance
# f3ba7a96-f713-40d9-9629    Credit Card  No Railcard     Standard     Advance
# b2471f11-4fe7-4c87-8ab4    Credit Card  No Railcard     Standard     Advance
# 2be00b45-0762-485e-a7a3    Contactless  No Railcard     Standard     Advance
# 4e1dcd88-3d95-44ef-99fa    Credit Card  No Railcard     Standard     Advance
# 1c74479d-85a4-4ba1-a607    Credit Card        Adult     Standard     Advance
# febf8dab-f808-46fa-bf2b    Contactless     Disabled     Standard     Advance
# 01df916f-4291-41ec-a37d    Credit Card  No Railcard     Standard     Advance
# a8cedba7-1923-459d-b046    Credit Card  No Railcard     Standard     Advance
#
#                          Price      Departure Station    Arrival Destination  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176     43      London Paddington  Liverpool Lime Street
# b0cdd1b0-f214-4197-be53     23     London Kings Cross                   York
# f3ba7a96-f713-40d9-9629      3  Liverpool Lime Street  Manchester Piccadilly
# b2471f11-4fe7-4c87-8ab4     13      London Paddington                Reading
# 2be00b45-0762-485e-a7a3     76  Liverpool Lime Street          London Euston
# 4e1dcd88-3d95-44ef-99fa     35     London Kings Cross                   York
# 1c74479d-85a4-4ba1-a607      2          London Euston                 Oxford
# febf8dab-f808-46fa-bf2b      2  Liverpool Lime Street  Manchester Piccadilly
# 01df916f-4291-41ec-a37d     37          London Euston                   York
# a8cedba7-1923-459d-b046     13      London Paddington                Reading
#
#                         Date of Journey Departure Time Arrival Time  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176      2024-01-01       11:00:00     13:30:00
# b0cdd1b0-f214-4197-be53      2024-01-01       09:45:00     11:35:00
# f3ba7a96-f713-40d9-9629      2024-01-02       18:15:00     18:45:00
# b2471f11-4fe7-4c87-8ab4      2024-01-01       21:30:00     22:30:00
# 2be00b45-0762-485e-a7a3      2024-01-01       16:45:00     19:00:00
# 4e1dcd88-3d95-44ef-99fa      2024-01-01       06:15:00     08:05:00
# 1c74479d-85a4-4ba1-a607      2024-01-01       22:30:00     23:40:00
# febf8dab-f808-46fa-bf2b      2024-01-01       00:00:00     00:30:00
# 01df916f-4291-41ec-a37d      2024-01-01       00:00:00     01:50:00
# a8cedba7-1923-459d-b046      2024-01-01       01:30:00     02:30:00
#
#                         Actual Arrival Time Journey Status Reason for Delay  \
# Transaction ID
# da8a6ba8-b3dc-4677-b176            13:30:00        On Time    Not Mentioned
# b0cdd1b0-f214-4197-be53            11:40:00        Delayed   Signal Failure
# f3ba7a96-f713-40d9-9629            18:45:00        On Time    Not Mentioned
# b2471f11-4fe7-4c87-8ab4            22:30:00        On Time    Not Mentioned
# 2be00b45-0762-485e-a7a3            19:00:00        On Time    Not Mentioned
# 4e1dcd88-3d95-44ef-99fa            08:05:00        On Time    Not Mentioned
# 1c74479d-85a4-4ba1-a607            23:40:00        On Time    Not Mentioned
# febf8dab-f808-46fa-bf2b            00:30:00        On Time    Not Mentioned
# 01df916f-4291-41ec-a37d            02:07:00        Delayed   Signal Failure
# a8cedba7-1923-459d-b046            02:30:00        On Time    Not Mentioned
#
#                         Refund Request
# Transaction ID
# da8a6ba8-b3dc-4677-b176             No
# b0cdd1b0-f214-4197-be53             No
# f3ba7a96-f713-40d9-9629             No
# b2471f11-4fe7-4c87-8ab4             No
# 2be00b45-0762-485e-a7a3             No
# 4e1dcd88-3d95-44ef-99fa             No
# 1c74479d-85a4-4ba1-a607             No
# febf8dab-f808-46fa-bf2b             No
# 01df916f-4291-41ec-a37d             No
# a8cedba7-1923-459d-b046             No

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Total number of journeys and net revenue (excluding cancelled trips)

# %%
valid_journeys = railway_cleaned[railway_cleaned['Journey Status'] != 'Cancelled']

total_journeys = valid_journeys.shape[0]
net_revenue = valid_journeys['Price'].sum()
net_revenue,total_journeys
# Out:
# (np.int64(696196), 29766)

# %% [markdown]
# ### Calc AVG Price Ticket

# %%
avg_ticket = railway_cleaned.groupby('Ticket Class')['Price'].mean()
avg_ticket = avg_ticket.round(0)
avg_ticket
# Out:
# Ticket Class
# First Class    49.0
# Standard       21.0
# Name: Price, dtype: float64

# %% [markdown]
# ### Ticket Class Most Commonly Purchased

# %%
ticket_count = railway_cleaned['Ticket Class'].value_counts()
ticket_count
# Out:
# Ticket Class
# Standard       28587
# First Class     3058
# Name: count, dtype: int64

# %% [markdown]
# ### Distribution of passengers by railcard status

# %%
railcard_count = railway_cleaned['Railcard'].value_counts()
railcard_count
# Out:
# Railcard
# No Railcard    20912
# Adult           4846
# Disabled        3088
# Senior          2799
# Name: count, dtype: int64

# %% [markdown]
# ### Peak Hours Passgeners Journey

# %%
railway_cleaned['hour'] = pd.to_datetime(railway_cleaned['Departure Time'],format='%H:%M:%S').dt.hour 
peak_hours = railway_cleaned['hour'].value_counts()
peak_hours.head(5)
# Out:
# hour
# 18    3111
# 6     3111
# 17    2887
# 7     2794
# 16    2300
# Name: count, dtype: int64

# %% [markdown]
# ### top arrival stations

# %%
top_arrival = railway_cleaned['Arrival Destination'].value_counts()
top_arrival.head(7)
# Out:
# Arrival Destination
# Birmingham New Street    7740
# Liverpool Lime Street    5021
# York                     4018
# Manchester Piccadilly    3968
# Reading                  3918
# London Euston            1565
# London St Pancras         749
# Name: count, dtype: int64

# %% [markdown]
# ### Top 5 cancellation reasons with number of trips and revenue lost

# %%
cancelled = railway_cleaned[railway_cleaned['Journey Status'] == 'Cancelled']
cancel_reason = cancelled.groupby('Reason for Delay').agg(cancelled_trips=('Reason for Delay','count'),
revenue_lost=('Price','sum'))
cancel_reason
# Out:
#                     cancelled_trips  revenue_lost
# Reason for Delay
# Signal Failure                  281          7327
# Signal failure                  238          5143
# Staff Shortage                  216          5221
# Staffing                        238          6271
# Technical Issue                 235          4958
# Traffic                         227          5280
# Weather                         236          7098
# Weather Conditions              208          4088

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Total number of journeys and net revenue (excluding cancelled trips)

# %%
railway_cleaned["Departure Time"] = pd.to_datetime(railway_cleaned["Departure Time"])
railway_cleaned["hour"] = railway_cleaned["Departure Time"].dt.hour
journeys_per_hour = railway_cleaned.groupby("hour").size()
plt.bar(journeys_per_hour.index, journeys_per_hour.values, color="darkblue" )
plt.title("Total Journeys by Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Journeys")
plt.show()

# %% [markdown]
# ### Calc AVG Price Ticket

# %%
avg_price =railway_cleaned.groupby("Ticket Class")["Price"].mean()
plt.pie(avg_price.values,labels=avg_price.index,autopct='%1.1f%%',colors=["darkblue","skyblue"],textprops={'color': 'white'})
plt.title("Average Ticket Price by Ticket Class")
plt.show()

# %% [markdown]
# ### Ticket Class Most Commonly Purchased

# %%
ticket_counts = railway_cleaned['Ticket Class'].value_counts().head(3)
ticket_counts.plot(kind='bar',color='#050d65')
plt.title("Most Purchased Ticket Classes")
plt.xlabel("Ticket Class")
plt.ylabel("Purchase Count")
plt.show()

# %% [markdown]
# ### Distribution of passengers by railcard status

# %%
railcard_counts = railway_cleaned['Railcard'].value_counts()
railcard_counts.plot(kind='pie', autopct='%1.1f%%',colors=["#0F1985","#054CA3","skyblue","#619fd2"],textprops={'color': 'white'})
plt.title("Passenger Distribution by Railcard")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Peak Hours Passgeners Journey

# %%
railway_cleaned['Departure Time'] = pd.to_datetime(railway_cleaned['Departure Time'])
railway_cleaned['hour'] = railway_cleaned['Departure Time'].dt.hour
peak_hours = railway_cleaned['hour'].value_counts().sort_values(ascending=False).head(5)
peak_hours.sort_index().plot(kind='bar',color='#061287')
plt.title("Peak Journey Hours")
plt.xlabel("Hour")
plt.ylabel("Number of Journeys")
plt.show()

# %% [markdown]
# ### top arrival stations

# %%
top_stations = railway_cleaned['Arrival Destination'].value_counts().head(7)
top_stations.plot(kind='bar',color='#0816a9')
plt.title("Top Arrival Stations")
plt.xlabel("Station")
plt.ylabel("Number of Arrivals")
plt.show()

# %% [markdown]
# ### Top 5 cancellation reasons with number of trips and revenue lost

# %%
cancelled = railway_cleaned[railway_cleaned['Journey Status'] == 'Cancelled']

cancel_reason = cancelled.groupby('Reason for Delay').agg(cancelled_trips=('Reason for Delay','count'),revenue_lost=('Price','sum')
).sort_values(by='cancelled_trips', ascending=False).head(5)
cancel_reason['cancelled_trips'].plot(kind='bar',color='darkblue')
plt.title("Top Cancellation Reasons")
plt.xlabel("Reason")
plt.ylabel("Cancelled Trips")
plt.show()

# %%
railway_cleaned.to_excel('By Python.xlsx', index=False)
